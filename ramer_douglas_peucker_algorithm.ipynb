# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreshthSaxena/ML/blob/master/ramer_douglas_peucker_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import sqrt
import matplotlib.pyplot as plt

def distance(a, b):
    return  sqrt((a[0] - b[0]) ** 2 + (a[1] - b[1]) ** 2)


def point_line_distance(point, start, end):
    if (start == end):
        return distance(point, start)
    else:
        n = abs(
            (end[0] - start[0]) * (start[1] - point[1]) -
            (start[0] - point[0]) * (end[1] - start[1])
        )
        d = sqrt(
            (end[0] - start[0]) ** 2 + (end[1] - start[1]) ** 2
        )
        return n / d


def rdp(points, epsilon):
    dmax = 0.0
    index = 0
    for i in range(1, len(points) - 1):
        d = point_line_distance(points[i], points[0], points[-1])
        if d > dmax:
            index = i
            dmax = d

    if dmax >= epsilon:
        results = rdp(points[:index+1], epsilon)[:-1] + rdp(points[index:], epsilon)
    else:
        results = [points[0], points[-1]]

    return results

# %%
line = [(0,1),(1,0),(2,1),(3,0),(4,1),(5,0),(6,1),(7,0)]
rdp_line = rdp(line,1.0)

plt.plot([i[0] for i in line],[i[1] for i in line])

# %%
plt.plot([i[0] for i in rdp_line],[i[1] for i in rdp_line])

# %%
line = [(0,0),(1,0),(2,0),(2,1),(2,2),(1,2),(0,2),(0,1),(0,0)]
rdp_line = rdp(line,1.0)

plt.plot([i[0] for i in line],[i[1] for i in line])

# %%
plt.plot([i[0] for i in rdp_line],[i[1] for i in rdp_line])
